# %%
import tkinter as tk
from tkinter import *
import pandas as pd


def deptbutton():
    dept = dept_entry.get().lower
    name = name_entry.get().lower

    if dept = 

def welcomeMessage():
    window = tk.Toplevel(root)
    window.title = (f"{department} Window")
    window.geometry = ("750x400")

    welcome = tk.Label(window, text=f"Welcome {name}! You are one of us at GIG Logistics! \n")
    welcome.pack()
    body = tk.Label(window, text=f"You have been verified, Click the button below to see your fellow department members")
    body.pack()

    button = tk.Button(window, text=f"See Department Members", command=deptbutton)
    button.pack()
    button.config = (fg="black", bg="yellow")
